# %% [markdown]
# ### Problem 1: Social Media Example

# %%
from_member = input("Enter name of from member: ")
to_member = input("Enter name of to member: ")

olpoc_following = []
olpoc_followers = ["@chums"]

joaquin_following = ["@chums","@jobenilagan"]
joaquin_followers = ["@jobenilagan"]

chums_following = ["@bongolpoc","@miketan","@rudyang","@joeilagan"]
chums_followers = ["@joaquin","@joeilagan"]

joben_following = ["@eeebeee","@joeilagan","@chums","@joaquin"]
joben_followers = ["@joaquin","@joeilagan","@eeebeee"]

joe_following = ["@eeebeee","@jobenilagan","@chums"]
joe_followers = ["@chums","@jobenilagan","@eeebeee"]

elizabeth_following = ["@jobenilagan","@joeilagan"]
elizabeth_followers = ["@jobenilagan","@joeilagan"]

def relationship_status(from_member,to_member):
    
    if from_member == ("Joselito Olpoc"):
        handle1 = "@bongolpoc"
        if to_member == ("Matthew Uy"):
            handle2 = olpoc_followers[0]
            relationship = "is followed by"
            return (handle1 +" "+ relationship +" "+ handle2)
        elif to_member in ("Joaquin Gonzales","Joben Ilagan","Joe Ilagan","Elizabeth Ilagan"):
            relationship = None
            return relationship
        
    elif from_member == ("Joaquin Gonzales"):
        handle1 = "@joaquin"
        if to_member == ("Matthew Uy"):
            handle2 = joaquin_following[0]
            relationship = "is following"
            return (handle1 +" "+ relationship +" "+ handle2)
        elif to_member == ("Joben Ilagan"):
            handle2 = "@jobenilagan"
            relationship = "is friends with"
            return (handle1 +" "+ relationship +" "+ handle2)
        elif to_member == ("Joaquin Gonzales"):
            handle2 = "@joaquin"
            relationship = "is followed by"
            return (handle1 +" "+ relationship +" "+ handle2)
        elif to_member in ("Joselito Olpoc","Joe Ilagan","Elizabeth Ilagan"):
            relationship = None
            return relationship
        
    elif from_member == ("Matthew Uy"):
        handle1 = "@chums"
        if to_member == ("Joselito Olpoc"):
            handle2 = chums_following[0]
            relationship = "is following"
            return (handle1 +" "+ relationship +" "+ handle2)
        elif to_member == ("Joe Ilagan"):
            handle2 = chums_following[3]
            relationship = "is friends with"
            return (handle1 +" "+ relationship +" "+ handle2)
        elif to_member in ("Joben Ilagan","Elizabeth Ilagan"):
            relationship = None
            return relationship
        
    elif from_member == ("Joben Ilagan"):
        handle1 = "@jobenilagan"
        if to_member == ("Elizabeth Ilagan"):
            handle2 = joben_following[0]
            relationship = "is friends with"
            return (handle1 +" "+ relationship +" "+ handle2)
        elif to_member == ("Joe Ilagan"):
            handle2 = joben_following[1]
            relationship = "is friends with"
            return (handle1 +" "+ relationship +" "+ handle2)
        elif to_member == ("Joaquin Gonzales"):
            handle2 = joben_following[3]
            relationship = "is friends with"
            return (handle1 +" "+ relationship +" "+ handle2)
        elif to_member == ("Matthew Uy"):
            handle2 = joben_following[2]
            relationship = "is following"
            return (handle1 +" "+ relationship +" "+ handle2)
        elif to_member == ("Joselito Olpoc"):
            relationship = None
            return relationship
        
    elif from_member == ("Joe Ilagan"):
        handle1 = "@joeilagan"
        if to_member == ("Elizabeth Ilagan"):
            handle2 = joe_following[0]
            relationship = "is friends with"
            return (handle1 +" "+ relationship +" "+ handle2)
        elif to_member == ("Joben Ilagan"):
            handle2 = joe_following[1]
            relationship = "is friends with"
            return (handle1 +" "+ relationship +" "+ handle2)
        elif to_member == ("Matthew Uy"):
            handle2 = joe_following[2]
            relationship = "is friends with"
            return (handle1 +" "+ relationship +" "+ handle2)
        elif to_member in ("Joselito Olpoc","Joaquin Gonzales"):
            relationship = None
            return relationship
        
    elif from_member == ("Elizabeth Ilagan"):
        handle1 = "@eeebeee"
        if to_member == ("Joben Ilagan"):
            handle2 = elizabeth_following[0]
            relationship = "is friends with"
            return (handle1 +" "+ relationship +" "+ handle2)
        elif to_member == ("Joe Ilagan"):
            handle2 = elizabeth_following[1]
            relationship = "is friends with"
            return (handle1 +" "+ relationship +" "+ handle2)
        elif to_member in ("Joselito Olpoc","Matthew Uy","Joaquin Gonzales"):
            relationship = None
            return relationship
            

relationshipstatus = relationship_status(from_member,to_member)
print(relationshipstatus)
# Out:
# Enter name of from member: Joben Ilagan
# Enter name of to member: Joe Ilagan
# @jobenilagan is friends with @joeilagan

# %% [markdown]
# ### Problem 2: Tic Tac Toe

# %%
board1 = [
['X','X','O'],
['O','X','O'],
['O','','X'],
]

board2 = [
['X','X','O'],
['O','X','O'],
['','O','X'],
]

board3 = [
['O','X','O'],
['','O','X'],
['X','X','O'],
]

board4 = [
['X','X','X'],
['O','X','O'],
['O','','O'],
]

board5 = [
['X','X','O'],
['O','X','O'],
['X','','O'],
]

board6 = [
['X','X','O'],
['O','X','O'],
['X','',''],
]

boardnum = input("Enter board number (1-6): ")

def get_winner(boardnum):
    if boardnum == "1":
        board = board1
        row1 = board1[0]
        row2 = board1[1]
        row3 = board1[2]
        
        if row1[0] == row1[1] and row1[1] == row1[2]:
            winning_character = row1[0]
            return winning_character
        
        elif row2[0] == row2[1] and row2[1] == row2[2]:
            winning_character = row2[0]
            return winning_character
        
        elif row3[0] == row3[1] and row3[1] == row3[2]:
            winning_character = row3[0]
            return winning_character
        
        elif row1[0] == row2[0] and row2[0] == row3[0]:
            winning_character = row1[0]
            return winning_character
        
        elif row1[1] == row2[1] and row2[1] == row3[1]:
            winning_character = row1[1]
            return winning_character
        
        elif row1[2] == row2[2] and row2[2] == row3[2]:
            winning_character = row1[2]
            return winning_character
        
        elif row1[0] == row2[1] and row2[1] == row3[2]:
            winning_character = row1[0]
            return winning_character
        
        elif row1[2] == row2[1] and row2[1] == row3[0]:
            winning_character = row1[0]
            return winning_character
         
    elif boardnum == "2":
        board = board2
        row1 = board2[0]
        row2 = board2[1]
        row3 = board2[2]
        
        if row1[0] == row1[1] and row1[1] == row1[2]:
            winning_character = row1[0]
            return winning_character
        
        elif row2[0] == row2[1] and row2[1] == row2[2]:
            winning_character = row2[0]
            return winning_character
        
        elif row3[0] == row3[1] and row3[1] == row3[2]:
            winning_character = row3[0]
            return winning_character
        
        elif row1[0] == row2[0] and row2[0] == row3[0]:
            winning_character = row1[0]
            return winning_character
        
        elif row1[1] == row2[1] and row2[1] == row3[1]:
            winning_character = row1[1]
            return winning_character
        
        elif row1[2] == row2[2] and row2[2] == row3[2]:
            winning_character = row1[2]
            return winning_character
        
        elif row1[0] == row2[1] and row2[1] == row3[2]:
            winning_character = row1[0]
            return winning_character
        
        elif row1[2] == row2[1] and row2[1] == row3[0]:
            winning_character = row1[0]
            return winning_character
        
    elif boardnum == "3":
        board = board3
        row1 = board3[0]
        row2 = board3[1]
        row3 = board3[2]
        
        if row1[0] == row1[1] and row1[1] == row1[2]:
            winning_character = row1[0]
            return winning_character
        
        elif row2[0] == row2[1] and row2[1] == row2[2]:
            winning_character = row2[0]
            return winning_character
        
        elif row3[0] == row3[1] and row3[1] == row3[2]:
            winning_character = row3[0]
            return winning_character
        
        elif row1[0] == row2[0] and row2[0] == row3[0]:
            winning_character = row1[0]
            return winning_character
        
        elif row1[1] == row2[1] and row2[1] == row3[1]:
            winning_character = row1[1]
            return winning_character
        
        elif row1[2] == row2[2] and row2[2] == row3[2]:
            winning_character = row1[2]
            return winning_character
        
        elif row1[0] == row2[1] and row2[1] == row3[2]:
            winning_character = row1[0]
            return winning_character
        
        elif row1[2] == row2[1] and row2[1] == row3[0]:
            winning_character = row1[0]
            return winning_character
        
    elif boardnum == "4":
        board = board4
        row1 = board4[0]
        row2 = board4[1]
        row3 = board4[2]
        
        if row1[0] == row1[1] and row1[1] == row1[2]:
            winning_character = row1[0]
            return winning_character
        
        elif row2[0] == row2[1] and row2[1] == row2[2]:
            winning_character = row2[0]
            return winning_character
        
        elif row3[0] == row3[1] and row3[1] == row3[2]:
            winning_character = row3[0]
            return winning_character
        
        elif row1[0] == row2[0] and row2[0] == row3[0]:
            winning_character = row1[0]
            return winning_character
        
        elif row1[1] == row2[1] and row2[1] == row3[1]:
            winning_character = row1[1]
            return winning_character
        
        elif row1[2] == row2[2] and row2[2] == row3[2]:
            winning_character = row1[2]
            return winning_character
        
        elif row1[0] == row2[1] and row2[1] == row3[2]:
            winning_character = row1[0]
            return winning_character
        
        elif row1[2] == row2[1] and row2[1] == row3[0]:
            winning_character = row1[0]
            return winning_character
        
    elif boardnum == "5":
        board = board5
        row1 = board5[0]
        row2 = board5[1]
        row3 = board5[2]
        
        if row1[0] == row1[1] and row1[1] == row1[2]:
            winning_character = row1[0]
            return winning_character
        
        elif row2[0] == row2[1] and row2[1] == row2[2]:
            winning_character = row2[0]
            return winning_character
        
        elif row3[0] == row3[1] and row3[1] == row3[2]:
            winning_character = row3[0]
            return winning_character
        
        elif row1[0] == row2[0] and row2[0] == row3[0]:
            winning_character = row1[0]
            return winning_character
        
        elif row1[1] == row2[1] and row2[1] == row3[1]:
            winning_character = row1[1]
            return winning_character
        
        elif row1[2] == row2[2] and row2[2] == row3[2]:
            winning_character = row1[2]
            return winning_character
        
        elif row1[0] == row2[1] and row2[1] == row3[2]:
            winning_character = row1[0]
            return winning_character
        
        elif row1[2] == row2[1] and row2[1] == row3[0]:
            winning_character = row1[0]
            return winning_character
        
    elif boardnum == "6":
        board = board6
        row1 = board6[0]
        row2 = board6[1]
        row3 = board6[2]
        
        if row1[0] == row1[1] and row1[1] == row1[2]:
            winning_character = row1[0]
            return winning_character
        
        elif row2[0] == row2[1] and row2[1] == row2[2]:
            winning_character = row2[0]
            return winning_character
        
        elif row3[0] == row3[1] and row3[1] == row3[2]:
            winning_character = row3[0]
            return winning_character
        
        elif row1[0] == row2[0] and row2[0] == row3[0]:
            winning_character = row1[0]
            return winning_character
        
        elif row1[1] == row2[1] and row2[1] == row3[1]:
            winning_character = row1[1]
            return winning_character
        
        elif row1[2] == row2[2] and row2[2] == row3[2]:
            winning_character = row1[2]
            return winning_character
        
        elif row1[0] == row2[1] and row2[1] == row3[2]:
            winning_character = row1[0]
            return winning_character
        
        elif row1[2] == row2[1] and row2[1] == row3[0]:
            winning_character = row1[0]
            return winning_character
    
winner = get_winner(boardnum)
print(winner)
# Out:
# Enter board number (1-6): 1
# X

# %%
minutes = []

source = input("Enter source: ")
destination = input("Enter destination: ")

def eta(source,destination):
    
    if source == "ADMU" or source == "admu":
        if destination == "DLSU" or destination == "dlsu":
            minutes.append(35)
            mins = str(minutes[0])
            
            return("The ETA from ADMU to DLSU is" + " " + mins + " " + "mins.")
        
        elif destination == "UP" or destination == "up":
            minutes.append(90)
            mins = str(minutes[0])
            
            return("The ETA from ADMU to UP is" + " " + mins + " " + "mins.")
        
    elif source == "DLSU" or source == "dlsu":
        if destination == "ADMU" or destination == "admu":
            minutes.append(65)
            mins = str(minutes[0])
            
            return("The ETA from DLSU to ADMU is" + " " + mins + " " + "mins.")
        
        elif destination == "UP" or destination == "up":
            minutes.append(55)
            mins = str(minutes[0])
            
            return("The ETA from DLSU to UP is" + " " + mins + " " + "mins.")
        
    elif source == "UP" or source == "up":
        if destination == "DLSU" or destination == "dlsu":
            minutes.append(45)
            mins = str(minutes[0])
            
            return("The ETA from UP to DLSU is" + " " + mins + " " + "mins.")
        
        elif destination == "ADMU" or desination == "admu":
            minutes.append(10)
            mins = str(minutes[0])
            
            return("The ETA from UP to ADMU is" + " " + mins + " " + "mins.")
            
arrival = eta(source,destination)
print(arrival)
# Out:
# Enter source: ADMU
# Enter destination: UP
# The ETA from ADMU to UP is 90 mins.
